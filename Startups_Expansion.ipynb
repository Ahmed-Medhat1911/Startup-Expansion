# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Medhat1911/Startup-Expansion/blob/main/Startups_Expansion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Import Libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
#@title Import & Inspect daya
data=pd.read_excel("/content/startup-expansion.xlsx")
data
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
#@title Show basic insights about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
#@title Show stastical insights about data
data[["Marketing Spend","Revenue"]].describe().round(2)
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %%
#@title Preprocessing DATA

# %%
#@title Check null values
data.isnull().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
#@title Check Duplicates
data.duplicated().sum()
# Out:
# 0

# %%
#@title Convert type of store ID to categrical object
data["Store ID"]=data["Store ID"].astype("object")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    object
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 8.3+ KB

# %%
#@title Check count of each city
data["City"].value_counts()
# Out:
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: City, Length: 149, dtype: int64

# %%
#@title check Cities
data["City"].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
#@title check states
data["State"].unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
#@title Check count of each State
data["State"].value_counts()
# Out:
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: State, dtype: int64

# %%
#@title EDA

# %%
#@title Show 10 Random rows from the Data
data.sample(10)
# Out:
#     Store ID          City          State Sales Region New Expansion  \
# 83        84     Cambridge  Massachusetts     Region 1           Old
# 134      135    Santa Rosa     California     Region 2           Old
# 39        40    Cape Coral        Florida     Region 1           Old
# 106      107    South Bend        Indiana     Region 1           Old
# 79        80    Costa Mesa     California     Region 2           Old
# 41        42  Newport News       Virginia     Region 1           Old
# 31        32  Grand Rapids       Michigan     Region 1           Old
# 23        24       Burbank     California     Region 2           Old
# 75        76        Topeka         Kansas     Region 2           Old
# 73        74  Murfreesboro      Tennessee     Region 2           Old
#
#      Marketing Spend  Revenue
# 83              2779    21286
# 134             3067    59060
# 39              2886    52250
# 106             3005    21953
# 79              2275    41361
# ...

# %%
#@title Show count of new Expansion vs old
data["New Expansion"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#@title Show count of Sales region
data["Sales Region"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#@title Compare new and old with city
data[data["New Expansion"]=="Old"].groupby("City").sum()["Revenue"].nlargest(10)
# Out:
# <ipython-input-38-0b806ecbe749>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data[data["New Expansion"]=="Old"].groupby("City").sum()["Revenue"].nlargest(10)
# City
# Rochester         83005
# Little Rock       68828
# Grand Rapids      65475
# Oxnard            64302
# Fontana           63027
# Providence        62337
# Birmingham        60338
# Overland Park     59887
# San Bernardino    59870
# Worcester         59840
# Name: Revenue, dtype: int64

# %%
data[data["New Expansion"]=="New"].groupby("City").sum()["Revenue"].nlargest(10)
# Out:
# <ipython-input-39-01014af463b0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data[data["New Expansion"]=="New"].groupby("City").sum()["Revenue"].nlargest(10)
# City
# Brownsville         63148
# Chattanooga         55357
# Rancho Cucamonga    52366
# Glendale            49376
# Tempe               48954
# Joliet              48315
# Rockford            43377
# Thousand Oaks       40141
# Paterson            34603
# College Station     22457
# Name: Revenue, dtype: int64

# %%
#@title Calculate Profit
data["Profit"]=data["Revenue"]-data["Marketing Spend"]
data
# Out:
#     Store ID             City       State Sales Region New Expansion  \
# 0          1           Peoria     Arizona     Region 2           Old
# 1          2          Midland       Texas     Region 2           Old
# 2          3          Spokane  Washington     Region 2           Old
# 3          4           Denton       Texas     Region 2           Old
# 4          5    Overland Park      Kansas     Region 2           Old
# ..       ...              ...         ...          ...           ...
# 145      146         Paterson  New Jersey     Region 1           New
# 146      147      Brownsville       Texas     Region 2           New
# 147      148         Rockford    Illinois     Region 1           New
# 148      149  College Station       Texas     Region 2           New
# 149      150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit
# 0               2601    48610   46009
# 1               2727    45689   42962
# ...

# %%
#@title Calculate Return on marketing spend
data["ROMS"]=(data["Profit"]/data["Marketing Spend"])*100
data["ROMS%"]=data["ROMS"]/100
data
# Out:
#     Store ID             City       State Sales Region New Expansion  \
# 0          1           Peoria     Arizona     Region 2           Old
# 1          2          Midland       Texas     Region 2           Old
# 2          3          Spokane  Washington     Region 2           Old
# 3          4           Denton       Texas     Region 2           Old
# 4          5    Overland Park      Kansas     Region 2           Old
# ..       ...              ...         ...          ...           ...
# 145      146         Paterson  New Jersey     Region 1           New
# 146      147      Brownsville       Texas     Region 2           New
# 147      148         Rockford    Illinois     Region 1           New
# 148      149  College Station       Texas     Region 2           New
# 149      150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit         ROMS      ROMS%
# 0               2601    48610   46009  1768.896578  17.688966
# ...

# %%
#@title Export DATA as CSV FILE
data.to_csv("startups.csv")
